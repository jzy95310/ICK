# %% [markdown]
# This script is only used for testing the actual running time of ICKy compared to vanilla neural networks (NNs) and Gaussian processes (GPs).

# %%
import sys
import time
sys.path.insert(0, '../../')
import torch
import numpy as np
from tqdm.notebook import tqdm

from model.ick import ICK
from utils.train import Trainer
from kernels.kernel_fn import *
from utils.helpers import *

import gpytorch
from gpytorch.kernels import LinearKernel, SpectralMixtureKernel
from torch.distributions.multivariate_normal import MultivariateNormal

# To make this notebook's output stable across runs
np.random.seed(2020)
torch.manual_seed(2020)
torch.cuda.manual_seed(2020)
torch.cuda.manual_seed_all(2020)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ### 1. Generate synthetic data

# %%
N = 1500
x = torch.rand(N,1)
cov_module = LinearKernel()
cov_lin = cov_module(x).evaluate().detach()
t = torch.linspace(0,2,N).reshape(-1,1)
cov_module = SpectralMixtureKernel(num_mixtures=2)
cov_sm = cov_module(t).evaluate().detach()
cov = cov_lin*cov_sm + torch.eye(cov_lin.shape[0])*1e-3
mv_normal_mul = MultivariateNormal(loc=torch.zeros(N),covariance_matrix=cov)
y = mv_normal_mul.sample()

data, target = [x.numpy(), t.numpy()], y.numpy()
x_train, y_train, x_val, y_val, x_test, y_test = train_val_test_split(
    data, target, shuffle_data=True, train_range=(0.,1.), random_seed=2020)
data_generators = create_generators_from_data(x_train, y_train, x_test, y_test, x_val, y_val, train_batch_size=100)

# %% [markdown]
# ### 2. Train ICKy and record runtime

# %%
kernel_assignment = ['ImplicitDenseNetKernel', 'ImplicitNystromKernel']
kernel_params = {
    'ImplicitDenseNetKernel':{
        'input_dim': 1,
        'latent_feature_dim': 16,
        'num_blocks': 1, 
        'num_layers_per_block': 1, 
        'num_units': 64
    }, 
    'ImplicitNystromKernel': {
        'kernel_func': spectral_mixture_kernel_1d_nys, 
        'params': ['weight','mean','cov','noise'], 
        'vals': [[1.0,0.0],[0.0,0.0], [0.5,0.5], 0.1], 
        'trainable': [True,True,True,True], 
        'alpha': 1e-5, 
        'num_inducing_points': 16, 
        'nys_space': [[0.,2.]]
    }
}

model = ICK(kernel_assignment, kernel_params)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
optim = 'adam'
optim_params = {
    'lr': 5e-5, 
    'weight_decay': 0.1
}
epochs, patience = 100, 100
trainer = Trainer(
    model=model,
    data_generators=data_generators,
    optim=optim,
    optim_params=optim_params, 
    model_save_dir=None,
    device=device,
    epochs=epochs,
    patience=patience
)
start = time.time()
trainer.train()
print("Total training time: {:.4f} seconds".format(time.time()-start))
# Out:
# Training started:
#
# Epoch 1/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2850
# Validation:
# 0s - loss 0.2465
#
# Epoch 2/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2765
# Validation:
# 0s - loss 0.2382
#
# Epoch 3/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2686
# Validation:
# 0s - loss 0.2303
#
# Epoch 4/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2613
# Validation:
# 0s - loss 0.2232
#
# Epoch 5/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2544
# Validation:
# 0s - loss 0.2166
#
# Epoch 6/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2481
# Validation:
# 0s - loss 0.2103
#
# Epoch 7/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2421
# Validation:
# 0s - loss 0.2046
#
# Epoch 8/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2365
# Validation:
# 0s - loss 0.1992
#
# Epoch 9/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.2313
# Validation:
# 0s - loss 0.1942
#
# Epoch 10/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2264
# Validation:
# 0s - loss 0.1896
#
# Epoch 11/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2218
# Validation:
# 0s - loss 0.1853
#
# Epoch 12/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2174
# Validation:
# 0s - loss 0.1812
#
# Epoch 13/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2133
# Validation:
# 0s - loss 0.1773
#
# Epoch 14/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2093
# Validation:
# 0s - loss 0.1736
#
# Epoch 15/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.2055
# Validation:
# 0s - loss 0.1700
#
# Epoch 16/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.2018
# Validation:
# 0s - loss 0.1668
#
# Epoch 17/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1984
# Validation:
# 0s - loss 0.1636
#
# Epoch 18/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1951
# Validation:
# 0s - loss 0.1606
#
# Epoch 19/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1918
# Validation:
# 0s - loss 0.1576
#
# Epoch 20/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1887
# Validation:
# 0s - loss 0.1549
#
# Epoch 21/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1857
# Validation:
# 0s - loss 0.1522
#
# Epoch 22/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1828
# Validation:
# 0s - loss 0.1496
#
# Epoch 23/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1800
# Validation:
# 0s - loss 0.1471
#
# Epoch 24/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1772
# Validation:
# 0s - loss 0.1448
#
# Epoch 25/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1746
# Validation:
# 0s - loss 0.1424
#
# Epoch 26/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1719
# Validation:
# 0s - loss 0.1400
#
# Epoch 27/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1693
# Validation:
# 0s - loss 0.1378
#
# Epoch 28/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1668
# Validation:
# 0s - loss 0.1356
#
# Epoch 29/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1644
# Validation:
# 0s - loss 0.1334
#
# Epoch 30/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1619
# Validation:
# 0s - loss 0.1314
#
# Epoch 31/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1595
# Validation:
# 0s - loss 0.1296
#
# Epoch 32/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.1573
# Validation:
# 0s - loss 0.1275
#
# Epoch 33/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.1550
# Validation:
# 0s - loss 0.1256
#
# Epoch 34/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1528
# Validation:
# 0s - loss 0.1237
#
# Epoch 35/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1506
# Validation:
# 0s - loss 0.1219
#
# Epoch 36/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1484
# Validation:
# 0s - loss 0.1200
#
# Epoch 37/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.1463
# Validation:
# 0s - loss 0.1183
#
# Epoch 38/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.1443
# Validation:
# 0s - loss 0.1165
#
# Epoch 39/100
# Learning rate: 0.000050
# 0s for 15 steps - 8ms/step - loss 0.1422
# Validation:
# 0s - loss 0.1147
#
# Epoch 40/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.1402
# Validation:
# 0s - loss 0.1130
#
# Epoch 41/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1382
# Validation:
# 0s - loss 0.1115
#
# Epoch 42/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1364
# Validation:
# 0s - loss 0.1098
#
# Epoch 43/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1344
# Validation:
# 0s - loss 0.1083
#
# Epoch 44/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1325
# Validation:
# 0s - loss 0.1068
#
# Epoch 45/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1308
# Validation:
# 0s - loss 0.1053
#
# Epoch 46/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1289
# Validation:
# 0s - loss 0.1039
#
# Epoch 47/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1272
# Validation:
# 0s - loss 0.1023
#
# Epoch 48/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1254
# Validation:
# 0s - loss 0.1009
#
# Epoch 49/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1237
# Validation:
# 0s - loss 0.0995
#
# Epoch 50/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1220
# Validation:
# 0s - loss 0.0982
#
# Epoch 51/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1204
# Validation:
# 0s - loss 0.0968
#
# Epoch 52/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1188
# Validation:
# 0s - loss 0.0955
#
# Epoch 53/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1172
# Validation:
# 0s - loss 0.0942
#
# Epoch 54/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1156
# Validation:
# 0s - loss 0.0929
#
# Epoch 55/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.1141
# Validation:
# 0s - loss 0.0917
#
# Epoch 56/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.1126
# Validation:
# 0s - loss 0.0905
#
# Epoch 57/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1111
# Validation:
# 0s - loss 0.0893
#
# Epoch 58/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1097
# Validation:
# 0s - loss 0.0881
#
# Epoch 59/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.1082
# Validation:
# 0s - loss 0.0870
#
# Epoch 60/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1069
# Validation:
# 0s - loss 0.0859
#
# Epoch 61/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1055
# Validation:
# 0s - loss 0.0848
#
# Epoch 62/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1041
# Validation:
# 0s - loss 0.0837
#
# Epoch 63/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1028
# Validation:
# 0s - loss 0.0826
#
# Epoch 64/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1015
# Validation:
# 0s - loss 0.0816
#
# Epoch 65/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.1003
# Validation:
# 0s - loss 0.0806
#
# Epoch 66/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0990
# Validation:
# 0s - loss 0.0797
#
# Epoch 67/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0978
# Validation:
# 0s - loss 0.0787
#
# Epoch 68/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0966
# Validation:
# 0s - loss 0.0777
#
# Epoch 69/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0954
# Validation:
# 0s - loss 0.0768
#
# Epoch 70/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0943
# Validation:
# 0s - loss 0.0759
#
# Epoch 71/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0931
# Validation:
# 0s - loss 0.0750
#
# Epoch 72/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0920
# Validation:
# 0s - loss 0.0741
#
# Epoch 73/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0909
# Validation:
# 0s - loss 0.0733
#
# Epoch 74/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.0898
# Validation:
# 0s - loss 0.0724
#
# Epoch 75/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0888
# Validation:
# 0s - loss 0.0715
#
# Epoch 76/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0878
# Validation:
# 0s - loss 0.0707
#
# Epoch 77/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0867
# Validation:
# 0s - loss 0.0700
#
# Epoch 78/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.0858
# Validation:
# 0s - loss 0.0692
#
# Epoch 79/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0848
# Validation:
# 0s - loss 0.0685
#
# Epoch 80/100
# Learning rate: 0.000050
# 0s for 15 steps - 7ms/step - loss 0.0839
# Validation:
# 0s - loss 0.0677
#
# Epoch 81/100
# Learning rate: 0.000050
# 0s for 15 steps - 7ms/step - loss 0.0829
# Validation:
# 0s - loss 0.0670
#
# Epoch 82/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0820
# Validation:
# 0s - loss 0.0663
#
# Epoch 83/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0811
# Validation:
# 0s - loss 0.0656
#
# Epoch 84/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.0802
# Validation:
# 0s - loss 0.0649
#
# Epoch 85/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0794
# Validation:
# 0s - loss 0.0642
#
# Epoch 86/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0785
# Validation:
# 0s - loss 0.0635
#
# Epoch 87/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0777
# Validation:
# 0s - loss 0.0630
#
# Epoch 88/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0769
# Validation:
# 0s - loss 0.0623
#
# Epoch 89/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0761
# Validation:
# 0s - loss 0.0617
#
# Epoch 90/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0753
# Validation:
# 0s - loss 0.0611
#
# Epoch 91/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0746
# Validation:
# 0s - loss 0.0605
#
# Epoch 92/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.0738
# Validation:
# 0s - loss 0.0599
#
# Epoch 93/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.0731
# Validation:
# 0s - loss 0.0594
#
# Epoch 94/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.0724
# Validation:
# 0s - loss 0.0588
#
# Epoch 95/100
# Learning rate: 0.000050
# 0s for 15 steps - 5ms/step - loss 0.0717
# Validation:
# 0s - loss 0.0583
#
# Epoch 96/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0710
# Validation:
# 0s - loss 0.0578
#
# Epoch 97/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0703
# Validation:
# 0s - loss 0.0572
#
# Epoch 98/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0696
# Validation:
# 0s - loss 0.0567
#
# Epoch 99/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0690
# Validation:
# 0s - loss 0.0562
#
# Epoch 100/100
# Learning rate: 0.000050
# 0s for 15 steps - 4ms/step - loss 0.0684
# Validation:
# 0s - loss 0.0557
#
# Training completed without early stopping.
# Total training time: 7.5078 seconds

# %% [markdown]
# ### 3. Train a plain NN with the same architecture as ICKy backbone and record runtime

# %%
# Concatenate x and t and input them into the plain NN
data, target = np.concatenate((x.numpy(), t.numpy()), axis=1), y.numpy()
x_train, y_train, x_val, y_val, x_test, y_test = train_val_test_split(
    data, target, shuffle_data=True, train_range=(0.,1.), random_seed=2020)
data_generators = create_generators_from_data(x_train, y_train, x_test, y_test, x_val, y_val, train_batch_size=100)

kernel_assignment = ['ImplicitDenseNetKernel']
kernel_params = {
    'ImplicitDenseNetKernel':{
        'input_dim': 2,
        'latent_feature_dim': 16,
        'num_blocks': 1, 
        'num_layers_per_block': 1, 
        'num_units': 64
    }
}

model = ICK(kernel_assignment, kernel_params)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
optim = 'adam'
optim_params = {
    'lr': 5e-5, 
    'weight_decay': 0.1
}
epochs, patience = 100, 100
trainer = Trainer(
    model=model,
    data_generators=data_generators,
    optim=optim,
    optim_params=optim_params, 
    model_save_dir=None,
    device=device,
    epochs=epochs,
    patience=patience
)
start = time.time()
trainer.train()
print("Total training time: {:.4f} seconds".format(time.time()-start))
# Out:
# Training started:
#
# Epoch 1/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3797
# Validation:
# 0s - loss 0.4008
#
# Epoch 2/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3743
# Validation:
# 0s - loss 0.3957
#
# Epoch 3/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3693
# Validation:
# 0s - loss 0.3909
#
# Epoch 4/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3647
# Validation:
# 0s - loss 0.3866
#
# Epoch 5/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3606
# Validation:
# 0s - loss 0.3827
#
# Epoch 6/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3568
# Validation:
# 0s - loss 0.3794
#
# Epoch 7/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3537
# Validation:
# 0s - loss 0.3764
#
# Epoch 8/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3508
# Validation:
# 0s - loss 0.3738
#
# Epoch 9/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3484
# Validation:
# 0s - loss 0.3715
#
# Epoch 10/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3462
# Validation:
# 0s - loss 0.3695
#
# Epoch 11/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3443
# Validation:
# 0s - loss 0.3680
#
# Epoch 12/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3428
# Validation:
# 0s - loss 0.3665
#
# Epoch 13/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3415
# Validation:
# 0s - loss 0.3652
#
# Epoch 14/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3403
# Validation:
# 0s - loss 0.3642
#
# Epoch 15/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3392
# Validation:
# 0s - loss 0.3634
#
# Epoch 16/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3384
# Validation:
# 0s - loss 0.3626
#
# Epoch 17/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3377
# Validation:
# 0s - loss 0.3619
#
# Epoch 18/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3371
# Validation:
# 0s - loss 0.3614
#
# Epoch 19/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3365
# Validation:
# 0s - loss 0.3609
#
# Epoch 20/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3361
# Validation:
# 0s - loss 0.3605
#
# Epoch 21/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3356
# Validation:
# 0s - loss 0.3602
#
# Epoch 22/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3353
# Validation:
# 0s - loss 0.3600
#
# Epoch 23/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3350
# Validation:
# 0s - loss 0.3597
#
# Epoch 24/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3348
# Validation:
# 0s - loss 0.3595
#
# Epoch 25/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3346
# Validation:
# 0s - loss 0.3593
#
# Epoch 26/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3344
# Validation:
# 0s - loss 0.3591
#
# Epoch 27/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3342
# Validation:
# 0s - loss 0.3590
#
# Epoch 28/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3341
# Validation:
# 0s - loss 0.3589
#
# Epoch 29/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3340
# Validation:
# 0s - loss 0.3588
#
# Epoch 30/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3339
# Validation:
# 0s - loss 0.3587
#
# Epoch 31/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3338
# Validation:
# 0s - loss 0.3587
#
# Epoch 32/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3337
# Validation:
# 0s - loss 0.3586
#
# Epoch 33/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3336
# Validation:
# 0s - loss 0.3585
#
# Epoch 34/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3335
# Validation:
# 0s - loss 0.3584
#
# Epoch 35/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3334
# Validation:
# 0s - loss 0.3584
#
# Epoch 36/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3334
# Validation:
# 0s - loss 0.3583
#
# Epoch 37/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3334
# Validation:
# 0s - loss 0.3582
#
# Epoch 38/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3333
# Validation:
# 0s - loss 0.3582
#
# Epoch 39/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3332
# Validation:
# 0s - loss 0.3582
#
# Epoch 40/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3332
# Validation:
# 0s - loss 0.3581
#
# Epoch 41/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3332
# Validation:
# 0s - loss 0.3581
#
# Epoch 42/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3332
# Validation:
# 0s - loss 0.3581
#
# Epoch 43/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3331
# Validation:
# 0s - loss 0.3580
#
# Epoch 44/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3331
# Validation:
# 0s - loss 0.3580
#
# Epoch 45/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3330
# Validation:
# 0s - loss 0.3580
#
# Epoch 46/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3330
# Validation:
# 0s - loss 0.3579
#
# Epoch 47/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3330
# Validation:
# 0s - loss 0.3579
#
# Epoch 48/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3330
# Validation:
# 0s - loss 0.3579
#
# Epoch 49/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3329
# Validation:
# 0s - loss 0.3578
#
# Epoch 50/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3329
# Validation:
# 0s - loss 0.3578
#
# Epoch 51/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3329
# Validation:
# 0s - loss 0.3578
#
# Epoch 52/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3328
# Validation:
# 0s - loss 0.3577
#
# Epoch 53/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3328
# Validation:
# 0s - loss 0.3577
#
# Epoch 54/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3328
# Validation:
# 0s - loss 0.3577
#
# Epoch 55/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3328
# Validation:
# 0s - loss 0.3577
#
# Epoch 56/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3328
# Validation:
# 0s - loss 0.3576
#
# Epoch 57/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3576
#
# Epoch 58/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3328
# Validation:
# 0s - loss 0.3576
#
# Epoch 59/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3576
#
# Epoch 60/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3576
#
# Epoch 61/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3576
#
# Epoch 62/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3576
#
# Epoch 63/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3575
#
# Epoch 64/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3575
#
# Epoch 65/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3575
#
# Epoch 66/100
# Learning rate: 0.000050
# 0s for 15 steps - 3ms/step - loss 0.3327
# Validation:
# 0s - loss 0.3575
#
# Epoch 67/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3575
#
# Epoch 68/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3575
#
# Epoch 69/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3575
#
# Epoch 70/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3575
#
# Epoch 71/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3574
#
# Epoch 72/100
# Learning rate: 0.000050
# 0s for 15 steps - 9ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3574
#
# Epoch 73/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3574
#
# Epoch 74/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3574
#
# Epoch 75/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3326
# Validation:
# 0s - loss 0.3574
#
# Epoch 76/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3574
#
# Epoch 77/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3574
#
# Epoch 78/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3574
#
# Epoch 79/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3574
#
# Epoch 80/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3574
#
# Epoch 81/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 82/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 83/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 84/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 85/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 86/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 87/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 88/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 89/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3573
#
# Epoch 90/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 91/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3573
#
# Epoch 92/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3325
# Validation:
# 0s - loss 0.3573
#
# Epoch 93/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3573
#
# Epoch 94/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3573
#
# Epoch 95/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3573
#
# Epoch 96/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3573
#
# Epoch 97/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3573
#
# Epoch 98/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3572
#
# Epoch 99/100
# Learning rate: 0.000050
# 0s for 15 steps - 2ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3572
#
# Epoch 100/100
# Learning rate: 0.000050
# 0s for 15 steps - 1ms/step - loss 0.3324
# Validation:
# 0s - loss 0.3572
#
# Training completed without early stopping.
# Total training time: 3.7410 seconds

# %% [markdown]
# ### 4. Train a GP with spectral mixture kernel and record runtime

# %%
class SpectralMixtureGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(SpectralMixtureGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.SpectralMixtureKernel(num_mixtures=2, ard_num_dims=2)
        self.covar_module.initialize_from_data(train_x, train_y)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)
    
likelihood = gpytorch.likelihoods.GaussianLikelihood()
gp = SpectralMixtureGPModel(torch.tensor(x_train), torch.tensor(y_train).view(-1,1), likelihood)

epochs, patience = 100, 100
gp.train()
likelihood.train()
optimizer = torch.optim.Adam(gp.parameters(), lr=5e-5)
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, gp)

best_loss, best_model_state_dict, trigger_times = 1e9, None, 0
num_epochs = tqdm(range(epochs), position=0, leave=True)
start = time.time()
for i in num_epochs:
    optimizer.zero_grad()
    output = gp(torch.tensor(x_train))
    loss = -mll(output, torch.tensor(y_train).float())
    loss.backward()
    num_epochs.set_description('Iter %d/%d - Loss: %.3f' % (
        i + 1, epochs, loss.item()
    ))
    optimizer.step()
    if loss.item() > best_loss:
        trigger_times += 1
        if trigger_times >= patience:
            if best_model_state_dict is not None:
                gp.load_state_dict(best_model_state_dict)
            break
    else:
        trigger_times = 0
        best_loss = loss.item()
        best_model_state_dict = gp.state_dict()
print("Total training time: {:.4f} seconds".format(time.time()-start))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Total training time: 18.4007 seconds
